# %%
pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.yaml").load("yolo11n.pt")
model = YOLO("yolo11s.yaml").load("yolo11s.pt")
model = YOLO("yolo11m.yaml").load("yolo11m.pt")

model = YOLO('yolo11s.pt')
# Out:
# Transferred 499/499 items from pretrained weights
# Transferred 499/499 items from pretrained weights
# Transferred 649/649 items from pretrained weights

# %% [markdown]
# <h1>TEST 01 베이스 학습

# %%
model.train(data='data.yaml', epochs=100, batch=16, imgsz=640,project='run_test01')
# Out:
# Ultralytics 8.3.228  Python-3.11.14 torch-2.6.0+cu124 CUDA:0 (NVIDIA RTX A4000, 16376MiB)
# ...

# %%
model.train(
    data='data.yaml',
    epochs=100,
    batch=16,
    imgsz=640,
    project='run_test01',
    name='augmentation',
    mosaic=1.0,       
    mixup=0.2,          
    hsv_h=0.015, hsv_s=0.7, hsv_v=0.4
)
# Out:
# Ultralytics 8.3.228  Python-3.11.14 torch-2.6.0+cu124 CUDA:0 (NVIDIA RTX A4000, 16376MiB)
# ...

# %%
model.train(
    data='data.yaml',
    epochs=100,
    batch=16,
    imgsz=640,
    project='run_test01',
    name='regularization',
    weight_decay=0.0005,
    optimizer='AdamW',
)
# Out:
# Ultralytics 8.3.228  Python-3.11.14 torch-2.6.0+cu124 CUDA:0 (NVIDIA RTX A4000, 16376MiB)
# ...

# %% [markdown]
# <h1>TEST 02 병합 학습

# %%
model.train(
    data='data.yaml',
    epochs=100,
    batch=16,
    imgsz=640,
    project='run_test02',
    name='augmented_v2',
    mosaic=1.0,       
    mixup=0.2,        
    hsv_h=0.015, hsv_s=0.7, hsv_v=0.4,  
    weight_decay=0.0005,      
    optimizer='AdamW',        
    )
# Out:
# New https://pypi.org/project/ultralytics/8.3.229 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.228  Python-3.11.14 torch-2.6.0+cu124 CUDA:0 (NVIDIA RTX A4000, 16376MiB)
# ...

# %%
from ultralytics import YOLO
model = YOLO('yolo11m.pt')
model.train(
    data="data.yaml",
    device=0,
    epochs=120,
    imgsz=640,
    lr0=0.001,
    optimizer='AdamW',
    batch=16,
    freeze=10,
    patience=30,
    hsv_h=0.015,
    hsv_s=0.5,
    hsv_v=0.3,
    degrees=2.0,
    translate=0.05,
    scale=0.8,
    fliplr=0.5,
    mosaic=1.0,
    mixup=0.1,
    project='run_test02',
    name='augmented_freeze10'
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.229 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.228  Python-3.11.14 torch-2.6.0+cu124 CUDA:0 (NVIDIA RTX A4000, 16376MiB)
# ...

# %% [markdown]
# <h1>TEST 03 모델 크기에 따른 성능

# %%
from ultralytics import YOLO

model = YOLO("yolo11s.pt")

model.train(
    data="data.yaml",
    epochs=120,
    imgsz=640,
    batch=16,
    optimizer="AdamW",
    lr0=0.001,
    lrf=0.15,
    weight_decay=0.002,
    momentum=0.93,
    warmup_epochs=5,
    cos_lr=True,
    patience=40,
    project="run_test03",
    name="reg_strong_mixup_s",
    device=0,
    val=True,
    hsv_h=0.015,
    hsv_s=0.8,
    hsv_v=0.4,
    degrees=10.0,
    translate=0.1,
    scale=0.15,
    shear=2.0,
    perspective=0.0008,
    flipud=0.0,
    fliplr=0.5,
    mosaic=1.0,
    mixup=0.3,
    copy_paste=0.1,
    dropout=0.05,
    cache=True,
    seed=42
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.229 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.228  Python-3.11.14 torch-2.6.0+cu124 CUDA:0 (NVIDIA RTX A4000, 16376MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")

model.train(
    data="data.yaml",
    epochs=120,
    imgsz=640,
    batch=16,
    optimizer="AdamW",
    lr0=0.001,
    lrf=0.15,
    weight_decay=0.002,
    momentum=0.93,
    warmup_epochs=5,
    cos_lr=True,
    patience=40,
    project="run_test03",
    name="reg_strong_mixup_n",
    device=0,
    val=True,
    hsv_h=0.015,
    hsv_s=0.8,
    hsv_v=0.4,
    degrees=10.0,
    translate=0.1,
    scale=0.15,
    shear=2.0,
    perspective=0.0008,
    flipud=0.0,
    fliplr=0.5,
    mosaic=1.0,
    mixup=0.3,
    copy_paste=0.1,
    dropout=0.05,
    cache=True,
    seed=42
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.229 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.228  Python-3.11.14 torch-2.6.0+cu124 CUDA:0 (NVIDIA RTX A4000, 16376MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolo11m.pt")

model.train(
    data="data.yaml",
    epochs=120,
    imgsz=640,
    batch=16,
    optimizer="AdamW",
    lr0=0.001,
    lrf=0.15,
    weight_decay=0.002,
    momentum=0.93,
    warmup_epochs=5,
    cos_lr=True,
    patience=40,
    device=0,
    val=True,
    hsv_h=0.015,
    hsv_s=0.8,
    hsv_v=0.4,
    degrees=10.0,
    translate=0.1,
    scale=0.15,
    shear=2.0,
    perspective=0.0008,
    flipud=0.0,
    fliplr=0.5,
    mosaic=1.0,
    mixup=0.3,
    copy_paste=0.1,
    dropout=0.05,
    cache=True,
    seed=42,
    project='run_test03',
    name='reg_strong_mixup_m'
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.229 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.228  Python-3.11.14 torch-2.6.0+cu124 CUDA:0 (NVIDIA RTX A4000, 16376MiB)
# ...
